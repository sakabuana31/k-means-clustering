# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans

# %%
sns.set()

data = pd.read_csv('/home/sakabuana31/DigitalSkola/Learning/HW_W11_K_MEANS_CLUSTER/input_data/sales_data.csv')

print(data)
# Out:
#          customer_name   income  spending
# 0       David Williams  6333892   1242949
# 1     Jordan Contreras  6267011   3909613
# 2        Stacey Knight  2192320   1906438
# 3         Kelly Barber  6167928   6738903
# 4    Jonathan Buchanan  6141797   4694040
# ..                 ...      ...       ...
# 195     Alexander West  1358103   7089107
# 196     Kevin Shepherd  3623621   8502975
# 197      John Bautista   992073    116173
# 198       David Austin  9997787   2886254
# 199  Elizabeth Richard  7539982   4470135
#
# [200 rows x 3 columns]

# %%
x = data.iloc[:, 1:3]

print(x)
# Out:
#       income  spending
# 0    6333892   1242949
# 1    6267011   3909613
# 2    2192320   1906438
# 3    6167928   6738903
# 4    6141797   4694040
# ..       ...       ...
# 195  1358103   7089107
# 196  3623621   8502975
# 197   992073    116173
# 198  9997787   2886254
# 199  7539982   4470135
#
# [200 rows x 2 columns]

# %%
max_cluster = 10
wcss=[]
number_clusters = range(1,max_cluster)

print(number_clusters)
# Out:
# range(1, 10)

# %%
for i in number_clusters:
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

print(wcss)
# Out:
# [3239448818428005.0, 1834219983528226.5, 1161717265383726.0, 777115581489745.1, 648864942212226.8, 536240653048969.3, 456966201536450.56, 372963721130204.7, 326114816854950.0]
# /home/sakabuana31/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/sakabuana31/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/sakabuana31/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(number_clusters,wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')

plt.savefig("/home/sakabuana31/DigitalSkola/Learning/HW_W11_K_MEANS_CLUSTER/output_data/The-Elbow-Method.png")
plt.show()

# %%
print("From figure above the best n_cluster=4")
# Out:
# From figure above the best n_cluster=3
