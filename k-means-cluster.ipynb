# %%
import getopt
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans
import matplotlib.ticker as mticker

# %%
data = pd.read_csv('/home/sakabuana31/DigitalSkola/Learning/HW_W11_K_MEANS_CLUSTER/input_data/sales_data.csv')

print(data)
# Out:
#          customer_name   income  spending
# 0       David Williams  6333892   1242949
# 1     Jordan Contreras  6267011   3909613
# 2        Stacey Knight  2192320   1906438
# 3         Kelly Barber  6167928   6738903
# 4    Jonathan Buchanan  6141797   4694040
# ..                 ...      ...       ...
# 195     Alexander West  1358103   7089107
# 196     Kevin Shepherd  3623621   8502975
# 197      John Bautista   992073    116173
# 198       David Austin  9997787   2886254
# 199  Elizabeth Richard  7539982   4470135
#
# [200 rows x 3 columns]

# %%
x = data.iloc[1::, [1, 2]].values

print(x)
# Out:
# [[6267011 3909613]
#  [2192320 1906438]
#  [6167928 6738903]
#  [6141797 4694040]
#  [1290836 6070814]
#  [4367870 5906092]
#  [3328995  791601]
#  [7646421 9175775]
#  [4504205 8303743]
#  [2004347 1921062]
#  [3834067 1106477]
#  [8235648 7608160]
#  [3334364 1092367]
#  [1632138 4665440]
#  [6464521 5349615]
#  [9676162 6623810]
#  [6082063 1086784]
#  [3034539 7292586]
#  [2347711 6998684]
#  [5848785 1017700]
#  [7658147 7347413]
#  [5915146  920375]
#  [8149008 6286288]
#  [3659282 2396736]
#  [9134970 6242587]
#  [ 631291 9318303]
#  [8087869 2635497]
#  [6006222 6362714]
#  [9070939 4417632]
#  [6730658 8022094]
#  [ 116306 3466704]
#  [1648110 8594794]
#  [6875315 6726366]
#  [2560829  452598]
#  [ 998413 5402672]
#  [2238362 7429628]
#  [9128516 4986735]
#  [5948434 4975101]
#  [6482722  283692]
#  [4755307 9267500]
#  [3609146 8423436]
#  [5853480 4867023]
#  [8903067 6341858]
#  [7436500 2092823]
#  [8127157  601757]
#  [9922586 4747632]
#  [9377736 9975013]
#  [3968226 6150008]
#  [2432727 4785591]
#  [6124264 5275258]
#  [7398681 2151293]
#  [4070385 7884910]
#  [9334213 6480941]
#  [8025072  150828]
#  [6164689 2079008]
#  [5227034 8066143]
#  [4935752 8930351]
#  [5030340 6474852]
#  [8081215 8251634]
#  [8109992 7638265]
#  [  34669 3632757]
#  [2335685 7169127]
#  [3680853 6588461]
#  [3398084 5710566]
#  [2473724 4673310]
#  [9848647 3024986]
#  [5070375 7893234]
#  [7820298 3076854]
#  [8411856 6587077]
#  [6434667 9902534]
#  [1795354 4319664]
#  [3284453 5956478]
#  [6628238 1542661]
#  [ 923499 8048981]
#  [1529869 7241350]
#  [1871987  571578]
#  [6356749 9174369]
#  [5972240 7478908]
#  [4968296 2607190]
#  [4795799 8284816]
#  [3013368 8775180]
#  [ 533743  721503]
#  [5204166 3355790]
#  [6304690 3705385]
#  [1888721 5758323]
#  [6555669 9734359]
#  [4013885  244622]
#  [9030080 8213241]
#  [4088492 2153712]
#  [7492708 2218020]
#  [7665963 4970949]
#  [2884304 7847600]
#  [9221942 5569336]
#  [5758324 3425706]
#  [4750159 6131582]
#  [  29649 7253191]
#  [7282761 6980937]
#  [2743868 7436459]
#  [6788452 4445375]
#  [3714899 1828330]
#  [5244464 4692171]
#  [ 961731 5577202]
#  [7556187   40556]
#  [2397799 3089870]
#  [9050066 7357651]
#  [1226543 1892289]
#  [4679390 6408655]
#  [6125147 1754993]
#  [ 415243 9152600]
#  [7890961 8064995]
#  [5527191 1641962]
#  [8684592 6338911]
#  [7339604  580425]
#  [5820835 8463943]
#  [9836870 3210762]
#  [9416036 2800957]
#  [4142513 8454703]
#  [5897727 8139087]
#  [6324214 9314148]
#  [3325392 6333844]
#  [8521973 2985937]
#  [6139897 9898416]
#  [3044611 7190661]
#  [7422126 3874105]
#  [6817804 6171550]
#  [3968649 1733246]
#  [6078748  643335]
#  [6797233 3985299]
#  [7211304 7958572]
#  [5474911 5668903]
#  [2811458 2225740]
#  [6297386 6394037]
#  [1986843 7967222]
#  [9658465 8418270]
#  [  24224 6533190]
#  [8403006  792460]
#  [2339544 9238228]
#  [7932062  554439]
#  [2314743 8948212]
#  [ 154914 7619291]
#  [1635636 1956972]
#  [3721987 1574184]
#  [ 418093 9409032]
#  [1916777 5823468]
#  [6376692 7430242]
#  [1628351 2671223]
#  [3637858 4792532]
#  [9380796 2148806]
#  [2325633 2772083]
#  [5887116  949719]
#  [5152500 3695895]
#  [2505490 9834157]
#  [7608223 7622178]
#  [6775858  558907]
#  [2989172 5896870]
#  [2970167 8267655]
#  [5540331  178199]
#  [6292711 7866187]
#  [6944357 9866697]
#  [4458120 3476668]
#  [4055500 2662231]
#  [4317706 6356147]
#  [4467509 1846285]
#  [6060917 4645314]
#  [5784602  492028]
#  [9441009  576765]
#  [2912741 7929558]
#  [9625709 7787335]
#  [1014494  375599]
#  [1956638 1595435]
#  [3064158 8001720]
#  [ 653007 9947263]
#  [4857492 9557490]
#  [8366081 9296950]
#  [5455089  541806]
#  [5830571 8027501]
#  [2008519 2826322]
#  [7567541 9630926]
#  [1405930 9655742]
#  [8977598 2137805]
#  [8668718 1698040]
#  [ 385862 8588949]
#  [5602756 2562494]
#  [6516127 7855635]
#  [9548916 3601480]
#  [8184942 2276748]
#  [4942253 7697035]
#  [1609086 4933297]
#  [ 129742 9457436]
#  [5087814 6671256]
#  [3951147 3211996]
#  [1726648 8578487]
#  [1970151  161995]
#  [4449450 8272570]
#  [1358103 7089107]
#  [3623621 8502975]
#  [ 992073  116173]
#  [9997787 2886254]
#  [7539982 4470135]]

# %%
n_cluster = 4
kmeans = KMeans(n_cluster, init = 'k-means++')
kmeans.fit_predict(x)
# Out:
# /home/sakabuana31/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([2, 1, 0, 2, 3, 3, 1, 0, 3, 1, 1, 0, 1, 1, 0, 0, 2, 3, 3, 2, 0, 2,
#        0, 1, 0, 3, 2, 0, 2, 0, 1, 3, 0, 1, 3, 3, 2, 0, 2, 0, 3, 2, 0, 2,
#        2, 2, 0, 3, 1, 0, 2, 3, 0, 2, 2, 0, 0, 0, 0, 0, 1, 3, 3, 3, 1, 2,
#        0, 2, 0, 0, 1, 3, 2, 3, 3, 1, 0, 0, 2, 0, 3, 1, 2, 2, 3, 0, 1, 0,
#        1, 2, 2, 3, 0, 2, 0, 3, 0, 3, 2, 1, 2, 3, 2, 1, 0, 1, 0, 2, 3, 0,
#        2, 0, 2, 0, 2, 2, 3, 0, 0, 3, 2, 0, 3, 2, 0, 1, 2, 2, 0, 0, 1, 0,
#        3, 0, 3, 2, 3, 2, 3, 3, 1, 1, 3, 3, 0, 1, 1, 2, 1, 2, 2, 3, 0, 2,
#        3, 3, 2, 0, 0, 1, 1, 3, 1, 2, 2, 2, 3, 0, 1, 1, 3, 3, 0, 0, 2, 0,
#        1, 0, 3, 2, 2, 3, 2, 0, 2, 2, 0, 3, 3, 0, 1, 3, 1, 3, 3, 3, 1, 2,
#        2], dtype=int32)

# %%
identified_clusters = kmeans.labels_

print(identified_clusters)
# Out:
# [2 1 0 2 3 3 1 0 3 1 1 0 1 1 0 0 2 3 3 2 0 2 0 1 0 3 2 0 2 0 1 3 0 1 3 3 2
#  0 2 0 3 2 0 2 2 2 0 3 1 0 2 3 0 2 2 0 0 0 0 0 1 3 3 3 1 2 0 2 0 0 1 3 2 3
#  3 1 0 0 2 0 3 1 2 2 3 0 1 0 1 2 2 3 0 2 0 3 0 3 2 1 2 3 2 1 0 1 0 2 3 0 2
#  0 2 0 2 2 3 0 0 3 2 0 3 2 0 1 2 2 0 0 1 0 3 0 3 2 3 2 3 3 1 1 3 3 0 1 1 2
#  1 2 2 3 0 2 3 3 2 0 0 1 1 3 1 2 2 2 3 0 1 1 3 3 0 0 2 0 1 0 3 2 2 3 2 0 2
#  2 0 3 3 0 1 3 1 3 3 3 1 2 2]

# %%
data_with_clusters = data.copy()

data_with_clusters
# Out:
#          customer_name   income  spending
# 0       David Williams  6333892   1242949
# 1     Jordan Contreras  6267011   3909613
# 2        Stacey Knight  2192320   1906438
# 3         Kelly Barber  6167928   6738903
# 4    Jonathan Buchanan  6141797   4694040
# ..                 ...      ...       ...
# 195     Alexander West  1358103   7089107
# 196     Kevin Shepherd  3623621   8502975
# 197      John Bautista   992073    116173
# 198       David Austin  9997787   2886254
# 199  Elizabeth Richard  7539982   4470135
#
# [200 rows x 3 columns]

# %%
fig = plt.figure(figsize=(12,10))
plt.scatter(x[identified_clusters == 0, 0], x[identified_clusters == 0, 1], s = 100,
            c = "green", label = "High Spend High Income")
plt.scatter(x[identified_clusters == 1, 0], x[identified_clusters == 1, 1], s = 100,
            c = "red", label = "Low Spend High Income")
plt.scatter(x[identified_clusters == 2, 0], x[identified_clusters == 2, 1], s = 100,
            c = "yellow", label = "Low Spend Low Income")
plt.scatter(x[identified_clusters == 3, 0], x[identified_clusters == 3, 1], s = 100,
            c = "blue", label = "High Spend Low Income")
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],
            s = 150, c = "black", label = "Centroids")
plt.title('Clustered Mall Using K-Means')
plt.xlabel('Income (Juta Rupiah)')
plt.ylabel('Spending (Juta Rupiah)')
plt.gca().xaxis.set_major_formatter(mticker.FixedFormatter(['{:}'.format(x/1e6) for x in plt.gca().get_xticks()]))
plt.gca().yaxis.set_major_formatter(mticker.FixedFormatter(['{:}'.format(y/1e6) for y in plt.gca().get_yticks()]))
plt.gca().xaxis.set_major_locator(mticker.FixedLocator(plt.gca().get_xticks()))
plt.gca().yaxis.set_major_locator(mticker.FixedLocator(plt.gca().get_yticks()))
plt.legend()
plt.savefig("/home/sakabuana31/DigitalSkola/Learning/HW_W11_K_MEANS_CLUSTER/output_data/Clustered-Mall-Using-K-Means.png")
plt.show()
# Out:
# /tmp/ipykernel_11008/3152302724.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().xaxis.set_major_formatter(mticker.FixedFormatter(['{:}'.format(x/1e6) for x in plt.gca().get_xticks()]))
# /tmp/ipykernel_11008/3152302724.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().yaxis.set_major_formatter(mticker.FixedFormatter(['{:}'.format(y/1e6) for y in plt.gca().get_yticks()]))
